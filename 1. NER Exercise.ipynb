# %% [markdown]
# <a href="https://colab.research.google.com/github/mritsurgeon/VO-AI-Workshop/blob/main/NER%20Step%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Pre-requisites

# %%
# !pip install tika spacy sentence_transformers chromadb plotly streamlit gliner-spacy ngrok pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Signup free to NgroK - Replace below API KEY
# https://ngrok.com/docs/getting-started/
#
# So you can expose UI

# %%
from pyngrok import ngrok
import nest_asyncio
ngrok.set_auth_token('2k5twjCsKYAWqpVddu9PcGPxXMb_3fg2CZpwDdHQDY9VM2Q6Q')
nest_asyncio.apply()

# %%
# !streamlit run https://raw.githubusercontent.com/mritsurgeon/VO-AI-Workshop/refs/heads/main/1.%20NER%20APP.py &>/dev/null&

# %% [markdown]
# Expose the UI & generate Ngrok Tunnel

# %%
url = ngrok.connect(8501)
print(f'Streamlit is running on {url}')
# Out:
# Streamlit is running on NgrokTunnel: "https://7a5e-34-91-47-105.ngrok-free.app" -> "http://localhost:8501"
